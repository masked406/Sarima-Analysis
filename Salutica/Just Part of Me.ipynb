# %%
import pandas as pd

# %%
raw_data = pd.read_csv('./Data/Raw_Data/outDashboard2RawV3_3.csv',header=0, index_col=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
drop_data = raw_data.drop(['Main_ID','Parameter_ID','Serial_Number','Status_Main','Station_ID','Station_Type',
                        'Parameter_Name','Failed_Date_Time','Failed_Measurement','Date_Time_Year',
                        'Date_Time_Month','Date_Time_Day','Date_Time_Weekday','Date_Time_WeekdayInt',
                        'Date_Time_YearWeekInt','Date_Time_Quarter'],axis=1)

# %%
drop_data
# Out:
#                     Date_Time   Database_Name  Date_Time_Hour  Status
# 0         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 1         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 2         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 3         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 4         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 5         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 6         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 7         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 8         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 9         2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 10        2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# 11        2018-10-05 15:00:55     DaTRUE2Left              15  Passed
# ...

# %% [markdown]
# # Split to each database

# %%
df_Left= drop_data.loc[drop_data['Database_Name'] == 'DaTRUE2Left']
df_Left
# Out:
#                    Date_Time Database_Name  Date_Time_Hour  Status
# 0        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 1        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 2        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 3        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 4        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 5        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 6        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 7        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 8        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 9        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 10       2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 11       2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 12       2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# ...

# %%
df_Right= drop_data.loc[drop_data['Database_Name'] == 'DaTRUE2Right']
df_Right
# Out:
#                     Date_Time Database_Name  Date_Time_Hour  Status
# 6320484   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320485   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320486   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320487   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320488   2018-10-05 16:02:24  DaTRUE2Right              16  Failed
# 6320489   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320490   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320491   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320492   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320493   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320494   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320495   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# 6320496   2018-10-05 16:02:24  DaTRUE2Right              16  Passed
# ...

# %%
df_Charger= drop_data.loc[drop_data['Database_Name'] == 'DaTRUE2Charger']
df_Charger
# Out:
#                     Date_Time   Database_Name  Date_Time_Hour  Status
# 12592753  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592754  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592755  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592756  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592757  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592758  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592759  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592760  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592761  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592762  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592763  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# 12592764  2017-05-09 19:06:31  DaTRUE2Charger              19  Passed
# ...

# %% [markdown]
# # Database Left
# ### Number of rows : 6320484
# #### Number of columns : 4

# %%
df_Left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6320484 entries, 0 to 6320483
# Data columns (total 4 columns):
# Date_Time         object
# Database_Name     object
# Date_Time_Hour    int64
# Status            object
# dtypes: int64(1), object(3)
# memory usage: 241.1+ MB

# %%
df_Left.groupby('Status').count()
# Out:
#         Date_Time  Database_Name  Date_Time_Hour
# Status
# Error      179158         179158          179158
# Failed     137729         137729          137729
# Passed    6003597        6003597         6003597

# %% [markdown]
# #### Split the Left database with the Pass, Fail, And Error

# %%
df_Left_Passed = df_Left.loc[df_Left['Status']=='Passed']
df_Left_Passed
# Out:
#                    Date_Time Database_Name  Date_Time_Hour  Status
# 0        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 1        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 2        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 3        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 4        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 5        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 6        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 7        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 8        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 9        2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 10       2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 11       2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# 12       2018-10-05 15:00:55   DaTRUE2Left              15  Passed
# ...

# %%
df_Left_Failed = df_Left.loc[df_Left['Status']=='Failed']
df_Left_Failed
# Out:
#                    Date_Time Database_Name  Date_Time_Hour  Status
# 292      2018-10-05 15:37:31   DaTRUE2Left              15  Failed
# 343      2018-10-05 15:40:25   DaTRUE2Left              15  Failed
# 581      2018-10-05 15:57:42   DaTRUE2Left              15  Failed
# 819      2018-10-05 16:13:57   DaTRUE2Left              16  Failed
# 946      2018-10-05 16:20:19   DaTRUE2Left              16  Failed
# 989      2018-10-05 16:23:19   DaTRUE2Left              16  Failed
# 1177     2018-10-05 16:35:53   DaTRUE2Left              16  Failed
# 1194     2018-10-05 16:36:53   DaTRUE2Left              16  Failed
# 1211     2018-10-05 16:37:07   DaTRUE2Left              16  Failed
# 1227     2018-10-05 16:37:37   DaTRUE2Left              16  Failed
# 1263     2018-10-05 15:03:35   DaTRUE2Left              15  Failed
# 1297     2018-10-05 15:05:43   DaTRUE2Left              15  Failed
# 1346     2018-10-05 15:22:48   DaTRUE2Left              15  Failed
# ...

# %%
df_Left_Error = df_Left.loc[df_Left['Status']=='Error']
df_Left_Error
# Out:
#                    Date_Time Database_Name  Date_Time_Hour Status
# 7497     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7498     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7499     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7500     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7501     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7502     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7503     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7504     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7505     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7506     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7507     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7508     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# 7509     2018-10-05 17:30:23   DaTRUE2Left              17  Error
# ...

# %% [markdown]
# # LEFT
# ## Drill down to the Prediction of Each Status
# ### 1. Passed

# %%
df_Left_Passed.drop(['Status'],axis=1,inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_Left_Passed
# Out:
#                    Date_Time Database_Name  Date_Time_Hour
# 0        2018-10-05 15:00:55   DaTRUE2Left              15
# 1        2018-10-05 15:00:55   DaTRUE2Left              15
# 2        2018-10-05 15:00:55   DaTRUE2Left              15
# 3        2018-10-05 15:00:55   DaTRUE2Left              15
# 4        2018-10-05 15:00:55   DaTRUE2Left              15
# 5        2018-10-05 15:00:55   DaTRUE2Left              15
# 6        2018-10-05 15:00:55   DaTRUE2Left              15
# 7        2018-10-05 15:00:55   DaTRUE2Left              15
# 8        2018-10-05 15:00:55   DaTRUE2Left              15
# 9        2018-10-05 15:00:55   DaTRUE2Left              15
# 10       2018-10-05 15:00:55   DaTRUE2Left              15
# 11       2018-10-05 15:00:55   DaTRUE2Left              15
# 12       2018-10-05 15:00:55   DaTRUE2Left              15
# 13       2018-10-05 15:00:55   DaTRUE2Left              15
# 14       2018-10-05 15:00:55   DaTRUE2Left              15
# ...

# %%
hourly_left = df_Left_Passed.sort_values('Date_Time_Hour')['Date_Time_Hour'].value_counts()
hourly_left
# Out:
# 11    408557
# 16    402642
# 14    401568
# 12    375451
# 7     369119
# 8     368503
# 9     364848
# 13    351966
# 17    295351
# 10    287485
# 15    281341
# 6     263098
# 20    181222
# 22    174634
# 1     168300
# 19    167915
# 0     166021
# 2     164239
# 23    163502
# 21    151613
# 18    147653
# 4     143719
# 3     137496
# 5      67354
# Name: Date_Time_Hour, dtype: int64

# %%
#hourly_left.colnames = ['Date_Time_Hour','Passed_Left_Frequency']
out_1 = hourly_left.to_csv('./Data/Hourly_Passed_Left.csv')

# %%
hourly_passed_left = pd.read_csv('./Data/Hourly_Passed_Left.csv',header=None)

# %%
x = pd.read_csv('./Data/Hourly_Passed_Left.csv',header=None)
x
# Out:
#      0       1
# 0   11  408557
# 1   16  402642
# 2   14  401568
# 3   12  375451
# 4    7  369119
# 5    8  368503
# 6    9  364848
# 7   13  351966
# 8   17  295351
# 9   10  287485
# 10  15  281341
# 11   6  263098
# 12  20  181222
# 13  22  174634
# 14   1  168300
# 15  19  167915
# 16   0  166021
# 17   2  164239
# 18  23  163502
# 19  21  151613
# 20  18  147653
# 21   4  143719
# 22   3  137496
# 23   5   67354

# %%
hourly_passed_left.columns = ['Date_Time_Hour','Passed_Left_Frequency']
hourly_passed_left.sort_values(by=['Date_Time_Hour'], inplace=True)
hourly_passed_left.reset_index(drop=True,inplace = True)
hourly_passed_left.drop('Date_Time_Hour',axis=1,inplace=True)

# %%
hourly_passed_left
# Out:
#     Passed_Left_Frequency
# 0                  166021
# 1                  168300
# 2                  164239
# 3                  137496
# 4                  143719
# 5                   67354
# 6                  263098
# 7                  369119
# 8                  368503
# 9                  364848
# 10                 287485
# 11                 408557
# 12                 375451
# 13                 351966
# 14                 401568
# 15                 281341
# 16                 402642
# 17                 295351
# 18                 147653
# 19                 167915
# 20                 181222
# 21                 151613
# 22                 174634
# 23                 163502

# %% [markdown]
# ### 2. Failed

# %%
df_Left_Failed.drop(['Status'],axis=1,inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
hourly_left_Failed = df_Left_Failed.sort_values('Date_Time_Hour')['Date_Time_Hour'].value_counts()
out_2 = hourly_left_Failed.to_csv('./Data/Hourly_Failed_Left.csv')

# %%
df_Left_Failed
#x = df_Left_Failed.sort_values('Date_Time_Hour')['Date_Time_Hour'].value_counts()
# Out:
#                    Date_Time Database_Name  Date_Time_Hour
# 292      2018-10-05 15:37:31   DaTRUE2Left              15
# 343      2018-10-05 15:40:25   DaTRUE2Left              15
# 581      2018-10-05 15:57:42   DaTRUE2Left              15
# 819      2018-10-05 16:13:57   DaTRUE2Left              16
# 946      2018-10-05 16:20:19   DaTRUE2Left              16
# 989      2018-10-05 16:23:19   DaTRUE2Left              16
# 1177     2018-10-05 16:35:53   DaTRUE2Left              16
# 1194     2018-10-05 16:36:53   DaTRUE2Left              16
# 1211     2018-10-05 16:37:07   DaTRUE2Left              16
# 1227     2018-10-05 16:37:37   DaTRUE2Left              16
# 1263     2018-10-05 15:03:35   DaTRUE2Left              15
# 1297     2018-10-05 15:05:43   DaTRUE2Left              15
# 1346     2018-10-05 15:22:48   DaTRUE2Left              15
# 1363     2018-10-05 15:22:59   DaTRUE2Left              15
# 1501     2018-10-05 15:34:00   DaTRUE2Left              15
# ...

# %%
hourly_failed_left = pd.read_csv('./Data/Hourly_Failed_Left.csv',header=None)
hourly_failed_left.columns = ['Date_Time_Hour','Failed_Left_Frequency']
hourly_failed_left.sort_values(by=['Date_Time_Hour'], inplace=True)
hourly_failed_left.reset_index(drop=True,inplace = True)
hourly_failed_left.drop('Date_Time_Hour',axis=1,inplace=True)
hourly_failed_left
# Out:
#     Failed_Left_Frequency
# 0                    4141
# 1                    4167
# 2                    4109
# 3                    3441
# 4                    3374
# 5                    1516
# 6                    5278
# 7                    7590
# 8                    7748
# 9                    7317
# 10                   6953
# 11                   8233
# 12                   8280
# 13                   7875
# 14                   8911
# 15                   6561
# 16                   8917
# 17                   6538
# 18                   4265
# 19                   4625
# 20                   4747
# 21                   4010
# 22                   4763
# 23                   4370

# %% [markdown]
# ### 3. Error

# %%
df_Left_Error.drop(['Status'],axis=1, inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
hourly_left_Error = df_Left_Error.sort_values('Date_Time_Hour')['Date_Time_Hour'].value_counts()
out_3 = hourly_left_Error.to_csv('./Data/Hourly_Error_Left.csv')

# %%
hourly_error_left = pd.read_csv('./Data/Hourly_Error_Left.csv',header=None)
hourly_error_left.columns = ['Date_Time_Hour','Error_Left_Frequency']
hourly_error_left.sort_values(by=['Date_Time_Hour'], inplace=True)
hourly_error_left.reset_index(drop=True,inplace = True)
hourly_error_left.drop('Date_Time_Hour',axis=1,inplace=True)
hourly_error_left
# Out:
#     Error_Left_Frequency
# 0                   5743
# 1                   5592
# 2                   4403
# 3                   3633
# 4                   2999
# 5                   1521
# 6                   9241
# 7                  11430
# 8                  12358
# 9                  11894
# 10                  8281
# 11                 13057
# 12                 11113
# 13                  9604
# 14                 11776
# 15                  6430
# 16                 10705
# 17                  9485
# 18                  5183
# 19                  5532
# 20                  5438
# 21                  3998
# 22                  3993
# 23                  5749

# %% [markdown]
#  ## Left Database(Status)
# ### Join the Passed, Failed, Error Altogether

# %%
join_1 = pd.merge(hourly_failed_left,hourly_error_left, how = 'outer',left_index=True, right_index=True)
join_1
# Out:
#     Failed_Left_Frequency  Error_Left_Frequency
# 0                    4141                  5743
# 1                    4167                  5592
# 2                    4109                  4403
# 3                    3441                  3633
# 4                    3374                  2999
# 5                    1516                  1521
# 6                    5278                  9241
# 7                    7590                 11430
# 8                    7748                 12358
# 9                    7317                 11894
# 10                   6953                  8281
# 11                   8233                 13057
# 12                   8280                 11113
# 13                   7875                  9604
# 14                   8911                 11776
# 15                   6561                  6430
# 16                   8917                 10705
# 17                   6538                  9485
# 18                   4265                  5183
# ...

# %%
join_all_status_hourly = pd.merge(join_1,hourly_passed_left, how = 'outer',left_index=True, right_index=True)
join_all_status_hourly
# Out:
#     Failed_Left_Frequency  Error_Left_Frequency  Passed_Left_Frequency
# 0                    4141                  5743                 166021
# 1                    4167                  5592                 168300
# 2                    4109                  4403                 164239
# 3                    3441                  3633                 137496
# 4                    3374                  2999                 143719
# 5                    1516                  1521                  67354
# 6                    5278                  9241                 263098
# 7                    7590                 11430                 369119
# 8                    7748                 12358                 368503
# 9                    7317                 11894                 364848
# 10                   6953                  8281                 287485
# 11                   8233                 13057                 408557
# ...

# %%
import matplotlib.pyplot as plt

# %%
ax2 = join_all_status_hourly.plot(y=['Failed_Left_Frequency','Error_Left_Frequency','Passed_Left_Frequency'],figsize=(15,10))
plt.title('Record of Status Per Hour')
plt.xlabel('Hour')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
#ax2.get_figure().savefig('./Data/Data_Visualization/Hourly_From_Each_Database.png',bbox_inches='tight')
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25.]),
#  <a list of 7 Text xticklabel objects>)

# %%
join_all_status_hourly.plot(y=['Failed_Left_Frequency','Error_Left_Frequency'],figsize=(15,10))

# %% [markdown]
# ## Prediction On Hours by Status

# %%
df_Left_Passed.head()
# Out:
#              Date_Time Database_Name  Date_Time_Hour
# 0  2018-10-05 15:00:55   DaTRUE2Left              15
# 1  2018-10-05 15:00:55   DaTRUE2Left              15
# 2  2018-10-05 15:00:55   DaTRUE2Left              15
# 3  2018-10-05 15:00:55   DaTRUE2Left              15
# 4  2018-10-05 15:00:55   DaTRUE2Left              15

# %%
df_Left_Passed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6003597 entries, 0 to 6320483
# Data columns (total 3 columns):
# Date_Time         object
# Database_Name     object
# Date_Time_Hour    int64
# dtypes: int64(1), object(2)
# memory usage: 183.2+ MB

# %% [markdown]
# # RIGHT Database

# %% [markdown]
# Repeat the step above

# %% [markdown]
# # CHARGER Database
